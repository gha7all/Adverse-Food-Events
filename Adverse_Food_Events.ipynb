# %%
import pandas as pd
import numpy as np
import warnings

warnings.filterwarnings(action='ignore')

# %%
data = pd.read_csv('CAERS_ASCII_2004_2017Q2.csv')
data
# Out:
#        RA_Report # RA_CAERS Created Date AEC_Event Start Date  \
# 0            65325              1/1/2004             8/4/2003
# 1            65325              1/1/2004             8/4/2003
# 2            65333              1/1/2004                  NaN
# 3            65335              1/1/2004           11/24/2003
# 4            65336              1/1/2004                  NaN
# ...            ...                   ...                  ...
# 90781       214516             6/29/2017            1/20/2017
# 90782       214516             6/29/2017            1/20/2017
# 90783       214516             6/29/2017            1/20/2017
# 90784       214604             6/30/2017                  NaN
# 90785       214610             6/30/2017                  NaN
#
#       PRI_Product Role                    PRI_Reported Brand/Product Name  \
# 0              Suspect      MIDWEST COUNTRY FAIR CHOCOLATE FLAVORED CHIPS
# ...

# %%
data.dropna(inplace=True)
data.reset_index(drop=True, inplace=True)
data
# Out:
#        RA_Report # RA_CAERS Created Date AEC_Event Start Date  \
# 0            65325              1/1/2004             8/4/2003
# 1            65325              1/1/2004             8/4/2003
# 2            65335              1/1/2004           11/24/2003
# 3            65345              1/1/2004           12/21/2003
# 4            65399              1/5/2004           11/22/2003
# ...            ...                   ...                  ...
# 35423       214478             6/29/2017            6/20/2017
# 35424       214479             6/29/2017            6/20/2017
# 35425       214516             6/29/2017            1/20/2017
# 35426       214516             6/29/2017            1/20/2017
# 35427       214516             6/29/2017            1/20/2017
#
#       PRI_Product Role                    PRI_Reported Brand/Product Name  \
# 0              Suspect      MIDWEST COUNTRY FAIR CHOCOLATE FLAVORED CHIPS
# ...

# %%
newborns_products = data.loc[data['CI_Age Unit'] == 'Month(s)']
newborns_products = newborns_products.drop(newborns_products[newborns_products.CI_Gender == "Not Available"].index)
newborns_products.reset_index(drop = True, inplace = True)
newborns_products
# Out:
#      RA_Report # RA_CAERS Created Date AEC_Event Start Date PRI_Product Role  \
# 0          65665             1/13/2004           12/31/2003          Suspect
# 1          65799             1/16/2004             1/1/2004          Suspect
# 2          65834             1/17/2004            1/10/2004          Suspect
# 3          65903             1/21/2004             9/9/2003          Suspect
# 4          65938             1/21/2004           12/28/2003          Suspect
# ..           ...                   ...                  ...              ...
# 836       209523             3/27/2017             3/3/2017          Suspect
# 837       210188             4/12/2017            4/21/2013          Suspect
# 838       211500              5/5/2017            1/20/2017          Suspect
# 839       211524              5/6/2017           11/25/2016          Suspect
# 840       211694             5/10/2017           10/25/2016          Suspect
#
# ...

# %%
uns = pd.Series(newborns_products['PRI_FDA Industry Name'].unique())
uns
# Out:
# 0                           Soft Drink/Water
# 1                             Baby Food Prod
# 2                Milk/Butter/Dried Milk Prod
# 3                                  Cosmetics
# 4                           Nuts/Edible Seed
# 5                           Fruit/Fruit Prod
# 6            Candy W/O Choc/Special/Chew Gum
# 7                Bakery Prod/Dough/Mix/Icing
# 8                 Cereal Prep/Breakfast Food
# 9                Food Sweeteners (Nutritive)
# 10       Dietary Conv Food/Meal Replacements
# 11             Vegetables/Vegetable Products
# 12                           Snack Food Item
# 13                                      Soup
# 14                            Ice Cream Prod
# 15       Mult Food Dinner/Grav/Sauce/Special
# 16                Filled Milk/Imit Milk Prod
# 17                           Prep Salad Prod
# 18                                Coffee/Tea
# 19    Vit/Min/Prot/Unconv Diet(Human/Animal)
# 20                        Cheese/Cheese Prod
# ...

# %%
np.median(newborns_products['CI_Age at Adverse Event'])
# Out:
# 8.0
